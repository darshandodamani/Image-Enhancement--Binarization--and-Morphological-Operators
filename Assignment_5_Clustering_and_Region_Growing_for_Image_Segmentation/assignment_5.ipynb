# %% [markdown]
# ## Task 1 – K-Means Clustering

# %% [markdown]
# a) Read the exemplary color image inputEx4_1.jpg and setup a three-dimensional RGB feature space (reshape).

# %%
import numpy as np
import cv2 as cv
import math
from matplotlib import pyplot as plt
from PIL import Image

# %%
# Load the image
image = Image.open('inputEx5_1.jpg')
image_rgb = image.convert('RGB')
image_array = np.array(image_rgb)
reshaped_image = image_array.reshape(image_array.shape[0], image_array.shape[1], 3)

# %%
# image = cv.imread('inputEx5_1.jpg')
# feature_space = image.reshape(-1, 3)
# image_rgb = cv.cvtColor(image, cv.COLOR_BGR2RGB)
plt.imshow(image)
plt.title(label='origial inputEx5_1 image')
plt.show()

# %% [markdown]
# b) Implement a simple k-means clustering approach (usage of built-in function not allowed) with random initialization (see lecture notes) to group the color features.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Reference: https://medium.com/machine-learning-algorithms-from-scratch/k-means-clustering-from-scratch-in-python-1675d38eee42
#
# The first step is to randomly select k centroids, where k is equal to the number of clusters you choose. Centroids are data points representing the center of a cluster. The main element of the algorithm works by a two-step process called expectation-maximization. The expectation step assigns each data point to its nearest centroid. Then, the maximization step computes the mean of all the points for each cluster and sets the new centroid. Here’s what the conventional version of the k-means algorithm looks like:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Random initalization
k = 5
clusters = {}
# for i in range (k):
#     clusters[i] = X[i]
